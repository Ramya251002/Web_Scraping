# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
Link = "https://www.flipkart.com/vivo-y200-5g-jungle-green-256-gb/product-reviews/itmdca298200fe9e?pid=MOBGXG5HWCZF9JUP&lid=LSTMOBGXG5HWCZF9JUPF7WFQ7&marketplace=FLIPKART"

# %%
amazon = requests.get(Link)

# %%
print(amazon)
# Out:
# <Response [200]>

# %%
amazon.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.9e9635.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
sorting_amazon = bs(amazon.content,"html.parser")

# %%
sorting_amazon
# Out:
# <!DOCTYPE html>
# ...

# %%
customer= sorting_amazon.find_all("p" , class_= "_2sc7ZR _2V5EHH")

# %%
print(customer)
# Out:
# [<p class="_2sc7ZR _2V5EHH">Ashok Kumar</p>, <p class="_2sc7ZR _2V5EHH">Rahul  Kumar</p>, <p class="_2sc7ZR _2V5EHH">Guruprasad Raul</p>, <p class="_2sc7ZR _2V5EHH">Rakmin k Sangma</p>, <p class="_2sc7ZR _2V5EHH">Walib  Khan </p>, <p class="_2sc7ZR _2V5EHH">vijay sai</p>, <p class="_2sc7ZR _2V5EHH">Lalji Shukla</p>, <p class="_2sc7ZR _2V5EHH">Ravi Kumar</p>, <p class="_2sc7ZR _2V5EHH">Gyanaranjan  Tripathy</p>, <p class="_2sc7ZR _2V5EHH">Anees Fathima</p>]

# %%
''' '''

# %%
customer_name = []
for i in range(len(customer)):
    customer_name.append(customer[i].get_text())

# %%
customer_name
# Out:
# ['Ashok Kumar',
#  'Rahul  Kumar',
#  'Guruprasad Raul',
#  'Rakmin k Sangma',
#  'Walib  Khan ',
#  'vijay sai',
#  'Lalji Shukla',
#  'Ravi Kumar',
#  'Gyanaranjan  Tripathy',
#  'Anees Fathima']

# %%
customer_review = sorting_amazon.find_all("div" , class_= "t-ZTKy")

# %%
customer_review
# Out:
# [<div class="t-ZTKy"><div><div class="">#Good battery backup<br/>#Nice cemara quality with aura light <br/>#Display brightness also superb <br/>#No face heating or hanging issue<br/>#Value for money <br/>09/10</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>,
#  <div class="t-ZTKy"><div><div class="">It's a very good ❣️ phone, very 🔥 very brilliant 😍</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>,
#  <div class="t-ZTKy"><div><div class="">Nice product 👌👌👌👌👌👌👌👌</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>,
#  <div class="t-ZTKy"><div><div class="">Nice  super</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>,
#  <div class="t-ZTKy"><div><div class="">Best Phone VIVO Y200 5G <br/>LOVE YOU ❤️💕💫</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>,
#  <div class="t-ZTKy"><div><div class="">Nice</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>,
# ...

# %%
customer_rev = []
for i in range(len(customer_review)):
    customer_rev.append(customer_review[i].get_text())

# %%
customer_rev
# Out:
# ['#Good battery backup#Nice cemara quality with aura light #Display brightness also superb #No face heating or hanging issue#Value for money 09/10READ MORE',
#  "It's a very good ❣️ phone, very 🔥 very brilliant 😍READ MORE",
#  'Nice product 👌👌👌👌👌👌👌👌READ MORE',
#  'Nice  superREAD MORE',
#  'Best Phone VIVO Y200 5G LOVE YOU ❤️💕💫READ MORE',
#  'NiceREAD MORE',
#  'All the features of this mobile are very good, the mobile is very goodREAD MORE',
#  'Very excellent performance,  camera is soo good. I suggest to everyone buy this phone.READ MORE',
#  'Camera quality is very good slim phone easy to carry design is very good function ☺️ excellentREAD MORE',
#  'Veriy nice awesomeREAD MORE']

# %%
''' customer_reviews = [i.strip("\n") for i in customer_rev ]'''
# Out:
# ' customer_reviews = [i.strip("\n") for i in customer_rev ]'

# %%
 len(customer_rev)
# Out:
# 10

# %%
len(customer_name)
# Out:
# 10

# %%
import pandas as pd

# %%
data = pd.DataFrame()

# %%
data["customer"] = customer_name
data["customer_review"] = customer_rev

# %%
data
# Out:
#                 customer                                    customer_review
# 0            Ashok Kumar  #Good battery backup#Nice cemara quality with ...
# 1           Rahul  Kumar  It's a very good ❣️ phone, very 🔥 very brillia...
# 2        Guruprasad Raul                     Nice product 👌👌👌👌👌👌👌👌READ MORE
# 3        Rakmin k Sangma                               Nice  superREAD MORE
# 4           Walib  Khan      Best Phone VIVO Y200 5G LOVE YOU ❤️💕💫READ MORE
# 5              vijay sai                                      NiceREAD MORE
# 6           Lalji Shukla  All the features of this mobile are very good,...
# 7             Ravi Kumar  Very excellent performance,  camera is soo goo...
# 8  Gyanaranjan  Tripathy  Camera quality is very good slim phone easy to...
# 9          Anees Fathima                        Veriy nice awesomeREAD MORE

# %%
data.to_csv("C:\\Users\\HP\\Documents\\Python Scripts\\dhapps\\dhaapps_output\\output.csv")
